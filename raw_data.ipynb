# %% [markdown]
# <a href="https://colab.research.google.com/github/codingsohyun/thesis_implementation/blob/main/raw_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive

drive.mount("/content/gdrive")
# Out:
# Mounted at /content/gdrive

# %%
import pandas as pd
import numpy as np

sas = pd.read_sas("./gdrive/MyDrive/심형석교수님/pums.sas7bdat")

# %%
sas
# Out:
#          FIPST SECTOR N07_EMPLOYER   RG  TABWGT  EMPLOYMENT_NOISY  \
# 0        b'23'  b'51'         b'E'  3.0     5.4               9.0
# 1        b'23'  b'44'         b'E'  0.0     1.0              74.0
# 2        b'23'  b'55'         b'E'  5.0     1.0               2.0
# 3        b'23'  b'54'         b'E'  0.0     1.0              34.0
# 4        b'23'  b'51'         b'E'  0.0     1.0             120.0
# ...        ...    ...          ...  ...     ...               ...
# 2165675  b'55'  b'31'         b'E'  0.0     1.0             250.0
# 2165676  b'55'  b'48'         b'E'  0.0     1.0              14.0
# 2165677  b'25'  b'31'         b'E'  0.0     1.0              74.0
# 2165678  b'34'  b'42'         b'E'  0.0     1.0               4.0
# 2165679  b'53'  b'42'         b'E'  0.0     1.0             180.0
#
#          PAYROLL_NOISY  RECEIPTS_NOISY   PCT1  PCT2  ...  NOBUSCRED  \
# 0                140.0           360.0   74.0  21.0  ...       b'0'
# ...

# %%
sas.shape
# Out:
# (2165680, 199)

# %%
# sas 파일의 데이터프레임
df = pd.DataFrame(sas)

# %%
# df[['PCT1', 'PCT2', 'PCT3', 'PCT4']]
# df[df['PCT1']== 100]
# df[['NUMOWNERS']]

# 'raw' dataframe only includes single-owner firms
raw = df[df['NUMOWNERS']== b'1'].reset_index(drop=True)
raw
# Out:
#         FIPST SECTOR N07_EMPLOYER   RG  TABWGT  EMPLOYMENT_NOISY  \
# 0       b'23'  b'44'         b'E'  0.0   1.000              14.0
# 1       b'23'  b'44'         b'E'  0.0   1.000              74.0
# 2       b'23'  b'23'         b'E'  0.0   1.000              34.0
# 3       b'23'  b'52'         b'N'  7.0  33.611               0.0
# 4       b'23'  b'11'         b'E'  0.0   1.000              14.0
# ...       ...    ...          ...  ...     ...               ...
# 663380  b'13'  b'53'         b'E'  0.0   1.000              14.0
# 663381  b'32'  b'53'         b'E'  0.0   1.000               7.0
# 663382  b'39'  b'53'         b'E'  0.0   1.000               3.0
# 663383  b'48'  b'53'         b'E'  0.0   1.000               4.0
# 663384  b'53'  b'42'         b'E'  0.0   1.000             180.0
#
#         PAYROLL_NOISY  RECEIPTS_NOISY   PCT1  PCT2  ...  NOBUSCRED  \
# 0              1200.0          8300.0  100.0   0.0  ...       b'0'
# ...

# %%
# 필요한 데이터만 가진 raw 데이터를 csv 파일로 저장
raw.to_csv('./gdrive/MyDrive/심형석교수님/rraw.csv', index=False)

# %% [markdown]
# ### raw 데이터 확인하기

# %%
# PCT가 전부 100인지 확인
raw['PCT_100'] = np.where((raw['PCT1'] == 100) | (raw['PCT2'] == 100) | (raw['PCT3'] == 100) | (raw['PCT4'] == 100), 1, 0)
(raw['PCT_100'] == 0).sum()
# Out:
# 7861

# %% [markdown]
# *   single-owner firm만 추출한 데이터라서 PCT 중 하나만이 전부 100일거라고 생각했는데 그렇지 않은 데이터가 7861개 있음 확인함

# %%
# raw_not_100.shape

# %%
raw_not_100 = raw[raw['PCT_100'] == 0]
raw_not_100[['PCT1', 'PCT2', 'PCT3', 'PCT4', 'EDUC1', 'EDUC2', 'EDUC3', 'EDUC4']].reset_index(drop=True)
# Out:
#       PCT1  PCT2  PCT3  PCT4 EDUC1 EDUC2 EDUC3 EDUC4
# 0     52.0  16.0  16.0  16.0  b'5'  b'3'  b'6'  b'6'
# 1     71.0  29.0   0.0   0.0  b'5'  b'6'  b'0'  b'0'
# 2     25.0  25.0  25.0  25.0  b'7'  b'7'  b'7'  b'7'
# 3     50.0  50.0   0.0   0.0  b'2'  b'6'  b'0'  b'0'
# 4     64.0  36.0   0.0   0.0  b'3'  b'0'  b'0'  b'0'
# ...    ...   ...   ...   ...   ...   ...   ...   ...
# 7856  54.0  42.0   3.0   1.0  b'6'  b'0'  b'0'  b'0'
# 7857  54.0  42.0   3.0   1.0  b'6'  b'0'  b'0'  b'0'
# 7858  54.0  42.0   3.0   1.0  b'6'  b'0'  b'0'  b'0'
# 7859  54.0  42.0   3.0   1.0  b'6'  b'0'  b'0'  b'0'
# 7860  90.0  10.0   0.0   0.0  b'6'  b'5'  b'0'  b'0'
#
# [7861 rows x 8 columns]
